# %% [markdown]
# # SLEAP Feature Extraction for Home Cage

# %% [markdown]
# Features that will be extracted:
# - head distance
# - res head-int head angle
# - res head-int hind distance
# - res head-int hind angle
# - int head-res hind distance
# - int head-res hind angle
# - hind distance
# - resident velocity
# - inrtuder velocity

# %% [markdown]
# Need to grab when a intruder is in and the identity of the intruder for downstream analysis
#
# Extra Features to include:
# - Brain region
# - mouse identity
# - standard zscored DA
# - Intuder social identity

# %% [markdown]
# Convert h5 file data to only include times when another intruder is in
#
# Convert frames to time to be able to line up DA values to times
#
# Extract features from frames

# %%
import os
import sys
from slp_exp_class import SleapExperiment

# %%
# NAc: #15616F
# mPFC: #FFAF00

experiment_path = r"C:\Users\alber\OneDrive\Desktop\PC_Lab\Photometry\Pilot_2\Combined_Cohorts\Home_Cage\SLEAP\test"
csv_path = r"C:\Users\alber\OneDrive\Desktop\PC_Lab\Photometry\Pilot_2\Combined_Cohorts\Home_Cage\SLEAP\test_csvs"
sleap_path = r"C:\Users\alber\OneDrive\Desktop\PC_Lab\Photometry\Pilot_2\Combined_Cohorts\Home_Cage\SLEAP\sleap_id_corrected"

# %%
exp = SleapExperiment(
    experiment_folder_path=experiment_path,
    behavior_folder_path=csv_path,
    sleap_folder_path=sleap_path,
    fps=10.0
)
# Out:
# Found Synapse note file: C:\Users\alber\OneDrive\Desktop\PC_Lab\Photometry\Pilot_2\Combined_Cohorts\Home_Cage\SLEAP\test\nn2-250120-072910\Notes.txt
# read from t=0s to t=1774.16s
# Found Synapse note file: C:\Users\alber\OneDrive\Desktop\PC_Lab\Photometry\Pilot_2\Combined_Cohorts\Home_Cage\SLEAP\test\p1-240508-084607\Notes.txt
# read from t=0s to t=1812.36s
# Found Synapse note file: C:\Users\alber\OneDrive\Desktop\PC_Lab\Photometry\Pilot_2\Combined_Cohorts\Home_Cage\SLEAP\test\p2-240508-101128\Notes.txt
# read from t=0s to t=1820.76s
# Found Synapse note file: C:\Users\alber\OneDrive\Desktop\PC_Lab\Photometry\Pilot_2\Combined_Cohorts\Home_Cage\SLEAP\test\pp1-250120-094415\Notes.txt
# read from t=0s to t=1864.97s
# Found Synapse note file: C:\Users\alber\OneDrive\Desktop\PC_Lab\Photometry\Pilot_2\Combined_Cohorts\Home_Cage\SLEAP\test\pp2-250121-123301\Notes.txt
# read from t=0s to t=1852.76s

# %%
exp.default_batch_process()
bout_definitions = [
    {'prefix': 'Short_Term', 'introduced': 'Short_Term_Introduced', 'removed': 'Short_Term_Removed'},
    {'prefix': 'Long_Term', 'introduced': 'Long_Term_Introduced', 'removed': 'Long_Term_Removed'},
    {'prefix': 'Novel', 'introduced': 'Novel_Introduced', 'removed': 'Novel_Removed'}
]
exp.group_extract_manual_annotations(bout_definitions=bout_definitions)
df = exp.extract_sleap_features()
# Out:
# Processing nn2-250120-072910...
# Processing p1-240508-084607...
# Processing p2-240508-101128...
# Processing pp1-250120-094415...
# Processing pp2-250121-123301...
# Processing behaviors for nn2-250120-072910...
# Processing behaviors for p1-240508-084607...
# Processing behaviors for p2-240508-101128...
# Processing behaviors for pp1-250120-094415...
# Processing behaviors for pp2-250121-123301...

# %%
exp.all_sleap_features
# Out:
# [       time_s brain_region mouse_identity  zscore_DA intruder_identity  \
#  0       180.6          NAc            nn2  -0.754077      Short_Term_1
#  1       180.7          NAc            nn2  -0.538230      Short_Term_1
#  2       180.8          NAc            nn2  -0.203720      Short_Term_1
#  3       180.9          NAc            nn2  -0.036774      Short_Term_1
#  4       181.0          NAc            nn2   0.050408      Short_Term_1
#  ...       ...          ...            ...        ...               ...
#  15041  1773.5          NAc            nn2   0.648638           Novel_1
#  15042  1773.6          NAc            nn2   0.648638           Novel_1
#  15043  1773.7          NAc            nn2   0.648638           Novel_1
#  15044  1773.8          NAc            nn2   0.648638           Novel_1
#  15045  1773.9          NAc            nn2   0.648638           Novel_1
#
#          head_dist   hind_dist  res_head_int_hind_dist  \
#  0      282.648696  286.772588              265.808599
#  1      270.555166  287.805233              270.524078
#  2      258.432852  287.974587              272.912598
#  3      246.284834  287.076529              273.191862
#  4      234.129310  285.006829              271.582236
#  ...           ...         ...                     ...
#  15041  209.766192  110.760377              160.938603
#  15042  215.219535  119.768548              166.849207
#  15043  220.192223  128.854941              172.856455
#  15044  224.570424  138.045860              179.072800
#  15045  228.244682  147.394236              185.648092
#
#         res_head_int_hind_angle  int_head_res_hind_dist  \
#  0                    -0.027132              277.586537
#  1                    -0.053932              265.749896
#  2                    -0.080019              254.663420
#  3                    -0.105853              244.042928
#  4                    -0.131789              233.691134
#  ...                        ...                     ...
#  15041                 2.015316              180.249534
#  15042                 2.073099              187.911678
#  15043                 2.134949              194.555431
#  15044                 2.201045              200.024344
#  15045                 2.271467              204.168800
#
#         int_head_res_hind_angle  resident_velocity  intruder_velocity Subject  \
#  0                     3.114768          43.988459          71.589673     nn2
#  1                     3.064875          40.681429          71.647760     nn2
#  2                     3.022936          34.305577          73.370442     nn2
#  3                     2.989251          28.405654          76.452938     nn2
#  4                     2.964000          22.981901          80.192820     nn2
#  ...                        ...                ...                ...     ...
#  15041                -0.424718           2.569354          92.706046     nn2
#  15042                -0.396345           4.447339          87.009530     nn2
#  15043                -0.370061           7.043566          80.934785     nn2
#  15044                -0.345181          10.090624          74.971632     nn2
#  15045                -0.321076          11.718487          72.344120     nn2
#
#        Mouse_ID Brain_Region
#  0          nn2         mPFC
#  1          nn2         mPFC
#  2          nn2         mPFC
#  3          nn2         mPFC
#  4          nn2         mPFC
#  ...        ...          ...
#  15041      nn2         mPFC
#  15042      nn2         mPFC
#  15043      nn2         mPFC
#  15044      nn2         mPFC
#  15045      nn2         mPFC
#
#  [15046 rows x 16 columns],
#         time_s brain_region mouse_identity  zscore_DA intruder_identity  \
#  0       183.0         mPFC             p1   1.505122      Short_Term_1
#  1       183.1         mPFC             p1   1.540284      Short_Term_1
#  2       183.2         mPFC             p1   1.651809      Short_Term_1
#  3       183.3         mPFC             p1   0.973008      Short_Term_1
#  4       183.4         mPFC             p1   1.066889      Short_Term_1
#  ...       ...          ...            ...        ...               ...
#  15186  1782.2         mPFC             p1   2.149688       Long_Term_1
#  15187  1782.3         mPFC             p1   1.973869       Long_Term_1
#  15188  1782.4         mPFC             p1   1.917394       Long_Term_1
#  15189  1782.5         mPFC             p1   2.104505       Long_Term_1
#  15190  1782.6         mPFC             p1   2.212372       Long_Term_1
#
#          head_dist   hind_dist  res_head_int_hind_dist  \
#  0      134.575613  163.650463              146.586948
#  1      136.893170  162.768491              149.503651
#  2      139.030993  161.858623              152.161941
#  3      140.997779  160.926392              154.579118
#  4      142.803652  159.977618              156.772571
#  ...           ...         ...                     ...
#  15186   84.840919   96.323651              120.110614
#  15187   86.964882   96.946391              120.015371
#  15188   88.791397   98.131727              120.687941
#  15189   90.060881  100.043405              122.060358
#  15190   90.535416  102.845928              124.026382
#
#         res_head_int_hind_angle  int_head_res_hind_dist  \
#  0                     2.940797              179.922125
#  1                     2.937797              179.321265
#  2                     2.935241              178.648690
#  3                     2.933093              177.913102
#  4                     2.931324              177.123422
#  ...                        ...                     ...
#  15186                 1.159588               15.517275
#  15187                 1.071096               17.309573
#  15188                 0.986225               19.721807
#  15189                 0.906768               22.809219
#  15190                 0.834244               26.644441
#
#         int_head_res_hind_angle  resident_velocity  intruder_velocity Subject  \
#  0                     0.647337          14.377279       0.000000e+00      p1
#  1                     0.651882          13.767423       0.000000e+00      p1
#  2                     0.655921          12.590748       0.000000e+00      p1
#  3                     0.659489          11.495966       0.000000e+00      p1
#  4                     0.662620          10.480951       2.842171e-13      p1
#  ...                        ...                ...                ...     ...
#  15186                -1.958839          51.737164       3.364268e+01      p1
#  15187                -1.998070          52.466636       3.170496e+01      p1
#  15188                -2.015295          52.988348       2.972378e+01      p1
#  15189                -2.014408          53.350115       2.777997e+01      p1
#  15190                -2.000361          53.514001       2.689033e+01      p1
#
#        Mouse_ID Brain_Region
#  0           p1         mPFC
#  1           p1         mPFC
#  2           p1         mPFC
#  3           p1         mPFC
#  4           p1         mPFC
#  ...        ...          ...
#  15186       p1         mPFC
#  15187       p1         mPFC
#  15188       p1         mPFC
#  15189       p1         mPFC
#  15190       p1         mPFC
#
#  [15191 rows x 16 columns],
#         time_s brain_region mouse_identity  zscore_DA intruder_identity  \
#  0       182.7         mPFC             p2   3.071475      Short_Term_1
#  1       182.8         mPFC             p2   3.004045      Short_Term_1
#  2       182.9         mPFC             p2   3.369459      Short_Term_1
#  3       183.0         mPFC             p2   3.740645      Short_Term_1
#  4       183.1         mPFC             p2   3.663655      Short_Term_1
#  ...       ...          ...            ...        ...               ...
#  15089  1773.9         mPFC             p2  -0.356007           Novel_1
#  15090  1774.0         mPFC             p2  -0.435637           Novel_1
#  15091  1774.1         mPFC             p2  -0.276725           Novel_1
#  15092  1774.2         mPFC             p2  -0.171916           Novel_1
#  15093  1774.3         mPFC             p2  -0.457372           Novel_1
#
#         head_dist   hind_dist  res_head_int_hind_dist  res_head_int_hind_angle  \
#  0      52.823369   87.282335              105.401085                -1.142137
#  1      56.893868   85.048086              110.687041                -1.102529
#  2      61.003000   83.226635              115.607748                -1.070060
#  3      64.982163   81.791685              120.136441                -1.043282
#  4      68.731464   80.716765              124.263380                -1.021085
#  ...          ...         ...                     ...                      ...
#  15089  91.360027  102.374006               13.971221                 0.259377
#  15090  88.627533   99.225400               12.823513                 0.228815
#  15091  85.933950   95.209774               12.117861                 0.159249
#  15092  83.498060   90.245219               12.018583                 0.047781
#  15093  81.687638   84.246125               12.740488                -0.092921
#
#         int_head_res_hind_dist  int_head_res_hind_angle  resident_velocity  \
#  0                   50.973382                -2.774493          34.174640
#  1                   48.262869                -2.770815          32.807767
#  2                   45.869889                -2.771514          30.157379
#  3                   43.769841                -2.777039          27.670161
#  4                   41.941150                -2.787738          25.344469
#  ...                       ...                      ...                ...
#  15089              177.700367                 3.111239          98.772082
#  15090              173.717999                 3.090075          89.520209
#  15091              168.325362                 3.081625          79.591401
#  15092              161.467852                 3.088807          69.978862
#  15093              153.217220                 3.115885          65.995645
#
#         intruder_velocity Subject Mouse_ID Brain_Region
#  0           0.000000e+00      p2       p2         mPFC
#  1           0.000000e+00      p2       p2         mPFC
#  2           0.000000e+00      p2       p2         mPFC
#  3           2.842171e-13      p2       p2         mPFC
#  4           2.842171e-13      p2       p2         mPFC
#  ...                  ...     ...      ...          ...
#  15089       7.149692e+01      p2       p2         mPFC
#  15090       5.974697e+01      p2       p2         mPFC
#  15091       4.659631e+01      p2       p2         mPFC
#  15092       3.206798e+01      p2       p2         mPFC
#  15093       2.448854e+01      p2       p2         mPFC
#
#  [15094 rows x 16 columns],
#         time_s brain_region mouse_identity  zscore_DA intruder_identity  \
#  0       184.8         mPFC            pp1   0.827924      Short_Term_1
#  1       184.9         mPFC            pp1   0.669995      Short_Term_1
#  2       185.0         mPFC            pp1   0.852030      Short_Term_1
#  3       185.1         mPFC            pp1   0.730814      Short_Term_1
#  4       185.2         mPFC            pp1   1.003522      Short_Term_1
#  ...       ...          ...            ...        ...               ...
#  15083  1788.1         mPFC            pp1   1.900153           Novel_1
#  15084  1788.2         mPFC            pp1   1.979659           Novel_1
#  15085  1788.3         mPFC            pp1   2.014436           Novel_1
#  15086  1788.4         mPFC            pp1   2.185945           Novel_1
#  15087  1788.5         mPFC            pp1   1.851715           Novel_1
#
#          head_dist   hind_dist  res_head_int_hind_dist  \
#  0       51.894479   92.925121               23.556031
#  1       50.488044   76.083934               36.240575
#  2       51.831358   62.112689               46.664984
#  3       54.392848   50.786904               54.895305
#  4       57.143682   41.882295               61.104512
#  ...           ...         ...                     ...
#  15083  424.009633  304.392772              370.645584
#  15084  418.489436  301.298487              366.030127
#  15085  411.526140  297.267467              359.760449
#  15086  403.018819  292.320301              351.725479
#  15087  392.866783  286.557748              341.828498
#
#         res_head_int_hind_angle  int_head_res_hind_dist  \
#  0                     1.796314              139.751337
#  1                     1.901851              124.506466
#  2                     1.945821              112.239248
#  3                     1.969850              102.652125
#  4                     1.985315               95.424151
#  ...                        ...                     ...
#  15083                 2.921375              355.913531
#  15084                 2.913837              352.069108
#  15085                 2.903849              347.730032
#  15086                 2.890923              342.893638
#  15087                 2.874422              337.567993
#
#         int_head_res_hind_angle  resident_velocity  intruder_velocity Subject  \
#  0                     0.458111          58.747248       0.000000e+00     pp1
#  1                     0.512394          53.197549       0.000000e+00     pp1
#  2                     0.568976          42.558049       0.000000e+00     pp1
#  3                     0.625163          32.841246       2.842171e-13     pp1
#  4                     0.677718          24.061266       2.842171e-13     pp1
#  ...                        ...                ...                ...     ...
#  15083                -0.322048          36.929189       6.542703e+00     pp1
#  15084                -0.331847          48.531080       6.570314e+00     pp1
#  15085                -0.343984          61.271294       6.666664e+00     pp1
#  15086                -0.358755          75.104989       6.887871e+00     pp1
#  15087                -0.376501          82.295375       7.063684e+00     pp1
#
#        Mouse_ID Brain_Region
#  0          pp1         mPFC
#  1          pp1         mPFC
#  2          pp1         mPFC
#  3          pp1         mPFC
#  4          pp1         mPFC
#  ...        ...          ...
#  15083      pp1         mPFC
#  15084      pp1         mPFC
#  15085      pp1         mPFC
#  15086      pp1         mPFC
#  15087      pp1         mPFC
#
#  [15088 rows x 16 columns],
#         time_s brain_region mouse_identity  zscore_DA intruder_identity  \
#  0       183.3         mPFC            pp2   2.070971      Short_Term_1
#  1       183.4         mPFC            pp2   2.791513      Short_Term_1
#  2       183.5         mPFC            pp2   2.130321      Short_Term_1
#  3       183.6         mPFC            pp2   1.627940      Short_Term_1
#  4       183.7         mPFC            pp2   1.197377      Short_Term_1
#  ...       ...          ...            ...        ...               ...
#  15111  1783.1         mPFC            pp2   2.132723      Short_Term_2
#  15112  1783.2         mPFC            pp2   2.106631      Short_Term_2
#  15113  1783.3         mPFC            pp2   1.467309      Short_Term_2
#  15114  1783.4         mPFC            pp2   1.572693      Short_Term_2
#  15115  1783.5         mPFC            pp2   2.043872      Short_Term_2
#
#          head_dist   hind_dist  res_head_int_hind_dist  \
#  0      310.644776  203.757586              249.072935
#  1      327.005351  203.183726              257.153427
#  2      340.688811  205.899377              265.902659
#  3      351.749806  211.327534              274.973367
#  4      360.374510  219.069163              284.156806
#  ...           ...         ...                     ...
#  15111   28.015425   47.017091               31.401251
#  15112   32.884557   44.424810               25.194530
#  15113   38.908681   42.189930               19.155543
#  15114   46.203691   44.066850               20.226584
#  15115   54.888027   54.393272               33.432478
#
#         res_head_int_hind_angle  int_head_res_hind_dist  \
#  0                    -2.714999              261.871384
#  1                    -2.677254              268.574603
#  2                    -2.654001              275.388481
#  3                    -2.643045              282.213768
#  4                    -2.642325              289.041746
#  ...                        ...                     ...
#  15111                -0.265644               93.717039
#  15112                -0.114315               95.511561
#  15113                 0.297181               97.829754
#  15114                 1.053969              100.910297
#  15115                 1.573695              105.027204
#
#         int_head_res_hind_angle  resident_velocity  intruder_velocity Subject  \
#  0                     0.600923          89.933089          91.080985     pp2
#  1                     0.616647          89.535527          77.425580     pp2
#  2                     0.619867          88.813680          51.251234     pp2
#  3                     0.612533          87.922054          27.505039     pp2
#  4                     0.596416          86.748981           8.924393     pp2
#  ...                        ...                ...                ...     ...
#  15111                 0.280283          17.291357           9.618206     pp2
#  15112                 0.241326          19.215945          17.318770     pp2
#  15113                 0.191729          21.765162          26.187619     pp2
#  15114                 0.132219          24.883488          36.218035     pp2
#  15115                 0.064234          26.607450          41.524754     pp2
#
#        Mouse_ID Brain_Region
#  0          pp2         mPFC
#  1          pp2         mPFC
#  2          pp2         mPFC
#  3          pp2         mPFC
#  4          pp2         mPFC
#  ...        ...          ...
#  15111      pp2         mPFC
#  15112      pp2         mPFC
#  15113      pp2         mPFC
#  15114      pp2         mPFC
#  15115      pp2         mPFC
#
#  [15116 rows x 16 columns]]

# %%
df
# Out:
#        time_s brain_region mouse_identity  zscore_DA intruder_identity  \
# 0       180.6          NAc            nn2  -0.754077      Short_Term_1
# 1       180.7          NAc            nn2  -0.538230      Short_Term_1
# 2       180.8          NAc            nn2  -0.203720      Short_Term_1
# 3       180.9          NAc            nn2  -0.036774      Short_Term_1
# 4       181.0          NAc            nn2   0.050408      Short_Term_1
# ...       ...          ...            ...        ...               ...
# 75530  1783.1         mPFC            pp2   2.132723      Short_Term_2
# 75531  1783.2         mPFC            pp2   2.106631      Short_Term_2
# 75532  1783.3         mPFC            pp2   1.467309      Short_Term_2
# 75533  1783.4         mPFC            pp2   1.572693      Short_Term_2
# 75534  1783.5         mPFC            pp2   2.043872      Short_Term_2
#
#         head_dist   hind_dist  res_head_int_hind_dist  \
# 0      282.648696  286.772588              265.808599
# 1      270.555166  287.805233              270.524078
# 2      258.432852  287.974587              272.912598
# 3      246.284834  287.076529              273.191862
# 4      234.129310  285.006829              271.582236
# ...           ...         ...                     ...
# 75530   28.015425   47.017091               31.401251
# 75531   32.884557   44.424810               25.194530
# 75532   38.908681   42.189930               19.155543
# 75533   46.203691   44.066850               20.226584
# 75534   54.888027   54.393272               33.432478
#
#        res_head_int_hind_angle  int_head_res_hind_dist  \
# 0                    -0.027132              277.586537
# 1                    -0.053932              265.749896
# 2                    -0.080019              254.663420
# 3                    -0.105853              244.042928
# 4                    -0.131789              233.691134
# ...                        ...                     ...
# 75530                -0.265644               93.717039
# 75531                -0.114315               95.511561
# 75532                 0.297181               97.829754
# 75533                 1.053969              100.910297
# 75534                 1.573695              105.027204
#
#        int_head_res_hind_angle  resident_velocity  intruder_velocity Subject  \
# 0                     3.114768          43.988459          71.589673     nn2
# 1                     3.064875          40.681429          71.647760     nn2
# 2                     3.022936          34.305577          73.370442     nn2
# 3                     2.989251          28.405654          76.452938     nn2
# 4                     2.964000          22.981901          80.192820     nn2
# ...                        ...                ...                ...     ...
# 75530                 0.280283          17.291357           9.618206     pp2
# 75531                 0.241326          19.215945          17.318770     pp2
# 75532                 0.191729          21.765162          26.187619     pp2
# 75533                 0.132219          24.883488          36.218035     pp2
# 75534                 0.064234          26.607450          41.524754     pp2
#
#       Mouse_ID Brain_Region
# 0          nn2         mPFC
# 1          nn2         mPFC
# 2          nn2         mPFC
# 3          nn2         mPFC
# 4          nn2         mPFC
# ...        ...          ...
# 75530      pp2         mPFC
# 75531      pp2         mPFC
# 75532      pp2         mPFC
# 75533      pp2         mPFC
# 75534      pp2         mPFC
#
# [75535 rows x 16 columns]

# %%
exp.save_sleap_features("home_cage_pose_DA.csv")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 exp.save_sleap_features("home_cage_pose_DA.csv")
#
# File c:\Users\alber\OneDrive\Documents\GitHub\Fiber_Photometry\Pose_Tracking\slp_exp_class.py:105, in SleapExperiment.save_sleap_features(self, out_csv)
#     103 def save_sleap_features(self, out_csv: str):
#     104     """Dump the concatenated SLEAP + DA feature table."""
# --> 105     self.all_sleap_features.to_csv(out_csv, index=False)
#
# AttributeError: 'list' object has no attribute 'to_csv'
