# %% [markdown]
# # Reward Training Analysis

# %% [markdown]
# Cohort 2

# %%
from rt_extension import Reward_Training
from pathlib import Path

# %%
# cohort = 'cohort_1_2'
# cohort = 'cohort_3'
cohort = 'combined'
day = '1'
# day ='10'
# brain_region = 'mPFC'
brain_region = 'NAc'

"""Cohort 1/2 Day 1 Experiment Path"""
# experiment_path = r"C:\Users\yezon\Padilla-Coreano_Lab\Albert_Cohort_3\Reward_Training\Day1\Cohort_1_2\mPFC"
experiment_path = r"C:\Users\yezon\Padilla-Coreano_Lab\Albert_Cohort_3\Reward_Training\Day1\Cohort_1_2\NAc"

"""Cohort 1/2 Day 10 Experiment Path"""
# experiment_path = r"C:\Users\yezon\Padilla-Coreano_Lab\Albert_Cohort_3\Reward_Training\Day10\Cohort_1_2\mPFC"
# experiment_path = r"C:\Users\yezon\Padilla-Coreano_Lab\Albert_Cohort_3\Reward_Training\Day10\Cohort_1_2\NAc"

"""Cohort 3 Day 1 Experiment Path"""
# experiment_path1 = r"C:\Users\yezon\Padilla-Coreano_Lab\Albert_Cohort_3\Reward_Training\Day1\Cohort_3\mPFC"
experiment_path1 = r"C:\Users\yezon\Padilla-Coreano_Lab\Albert_Cohort_3\Reward_Training\Day1\Cohort_3\NAc"

"""Cohort 3 Day 10 Experiment Path"""
# experiment_path1 = r"C:\Users\yezon\Padilla-Coreano_Lab\Albert_Cohort_3\Reward_Training\Day10\Cohort_3\mPFC"
# experiment_path1 = r"C:\Users\yezon\Padilla-Coreano_Lab\Albert_Cohort_3\Reward_Training\Day10\Cohort_3\NAc"

directory_path = Path(f'C:\\Users\\yezon\\Padilla-Coreano_Lab\\Albert_Cohort_3\\Reward_Training\\plots\\{cohort}\\{brain_region}\\{day}\\peth')
directory_path1 = Path(f'C:\\Users\\yezon\\Padilla-Coreano_Lab\\Albert_Cohort_3\\Reward_Training\\plots\\{cohort}\\{brain_region}\\{day}\\linear')
directory_path2 = Path(f'C:\\Users\\yezon\\Padilla-Coreano_Lab\\Albert_Cohort_3\\Reward_Training\\plots\\{cohort}\\{brain_region}\\{day}\\linear\\EI')
directory_path3 = Path(f'C:\\Users\\yezon\\Padilla-Coreano_Lab\\Albert_Cohort_3\\Reward_Training\\plots\\{cohort}\\{brain_region}\\{day}\\heatmaps')

directory_path.mkdir(parents=True, exist_ok=True)
directory_path1.mkdir(parents=True, exist_ok=True)
directory_path2.mkdir(parents=True, exist_ok=True)
directory_path3.mkdir(parents=True, exist_ok=True)

# %%
exp = Reward_Training(experiment_folder_path=experiment_path1, behavior_folder_path=None)
if cohort == 'combined':
    exp1 = Reward_Training(experiment_folder_path=experiment_path, behavior_folder_path=None)
# Out:
# read from t=0s to t=3853.69s
# read from t=0s to t=3851.09s
# read from t=0s to t=3863.41s
# read from t=0s to t=3846.39s
# read from t=0s to t=3853.69s
# read from t=0s to t=3853.69s
# read from t=0s to t=3851.09s
# read from t=0s to t=3851.09s
# read from t=0s to t=3863.41s
# read from t=0s to t=3863.41s
# read from t=0s to t=3846.39s
# read from t=0s to t=3846.39s
# Found Synapse note file: C:\Users\yezon\Padilla-Coreano_Lab\Albert_Cohort_3\Reward_Training\Day1\Cohort_1_2\NAc\n1-240529-073613\Notes.txt
# read from t=0s to t=1681.65s
# Found Synapse note file: C:\Users\yezon\Padilla-Coreano_Lab\Albert_Cohort_3\Reward_Training\Day1\Cohort_1_2\NAc\n2-240529-103052\Notes.txt
# read from t=0s to t=1683.1s
# Found Synapse note file: C:\Users\yezon\Padilla-Coreano_Lab\Albert_Cohort_3\Reward_Training\Day1\Cohort_1_2\NAc\n3-240529-131000\Notes.txt
# read from t=0s to t=1680.59s
# Found Synapse note file: C:\Users\yezon\Padilla-Coreano_Lab\Albert_Cohort_3\Reward_Training\Day1\Cohort_1_2\NAc\n4-240529-154627\Notes.txt
# read from t=0s to t=1681.05s
# Found Synapse note file: C:\Users\yezon\Padilla-Coreano_Lab\Albert_Cohort_3\Reward_Training\Day1\Cohort_1_2\NAc\n5-240901-064209\Notes.txt
# read from t=0s to t=1681.56s
# Found Synapse note file: C:\Users\yezon\Padilla-Coreano_Lab\Albert_Cohort_3\Reward_Training\Day1\Cohort_1_2\NAc\n6-240901-092648\Notes.txt
# read from t=0s to t=1681.46s
# Found Synapse note file: C:\Users\yezon\Padilla-Coreano_Lab\Albert_Cohort_3\Reward_Training\Day1\Cohort_1_2\NAc\n7-240901-115754\Notes.txt
# read from t=0s to t=2008.26s
# Found Synapse note file: C:\Users\yezon\Padilla-Coreano_Lab\Albert_Cohort_3\Reward_Training\Day1\Cohort_1_2\NAc\n1-240529-073613\Notes.txt
# read from t=0s to t=1681.65s
# Found Synapse note file: C:\Users\yezon\Padilla-Coreano_Lab\Albert_Cohort_3\Reward_Training\Day1\Cohort_1_2\NAc\n2-240529-103052\Notes.txt
# read from t=0s to t=1683.1s
# Found Synapse note file: C:\Users\yezon\Padilla-Coreano_Lab\Albert_Cohort_3\Reward_Training\Day1\Cohort_1_2\NAc\n3-240529-131000\Notes.txt
# read from t=0s to t=1680.59s
# Found Synapse note file: C:\Users\yezon\Padilla-Coreano_Lab\Albert_Cohort_3\Reward_Training\Day1\Cohort_1_2\NAc\n4-240529-154627\Notes.txt
# read from t=0s to t=1681.05s
# Found Synapse note file: C:\Users\yezon\Padilla-Coreano_Lab\Albert_Cohort_3\Reward_Training\Day1\Cohort_1_2\NAc\n5-240901-064209\Notes.txt
# read from t=0s to t=1681.56s
# Found Synapse note file: C:\Users\yezon\Padilla-Coreano_Lab\Albert_Cohort_3\Reward_Training\Day1\Cohort_1_2\NAc\n6-240901-092648\Notes.txt
# read from t=0s to t=1681.46s
# Found Synapse note file: C:\Users\yezon\Padilla-Coreano_Lab\Albert_Cohort_3\Reward_Training\Day1\Cohort_1_2\NAc\n7-240901-115754\Notes.txt
# read from t=0s to t=2008.26s

# %%
exp.rt_processing()
exp.create_df(experiment_path1)
if cohort == "combined":
    exp1.rt_processing()
    exp1.create_df(experiment_path)
    exp.combining_cohorts(exp1.df)
# Out:
# dict_items([('nn1_nn2-250124-052535', <trial_class.Trial object at 0x00000290BA1C3290>), ('nn3_nn4-250124-064620', <trial_class.Trial object at 0x00000290BA9683B0>), ('nn5_nn6-250124-111148', <trial_class.Trial object at 0x00000290BABC3D70>), ('nn7_nn8-250124-122758', <trial_class.Trial object at 0x00000290BAB20530>), ('nn1-250124-052535', <trial_class.Trial object at 0x00000290BABC3CE0>), ('nn2-250124-052535', <trial_class.Trial object at 0x00000290BABEC380>), ('nn3-250124-064620', <trial_class.Trial object at 0x00000290F98937A0>), ('nn4-250124-064620', <trial_class.Trial object at 0x00000290F9891940>), ('nn5-250124-111148', <trial_class.Trial object at 0x00000290F98918E0>), ('nn6-250124-111148', <trial_class.Trial object at 0x00000290BA7AE540>), ('nn7-250124-122758', <trial_class.Trial object at 0x00000290F9892510>), ('nn8-250124-122758', <trial_class.Trial object at 0x000002909817BE00>)])
# Reward Training Processing nn1_nn2-250124-052535...
# Reward Training Processing nn3_nn4-250124-064620...
# Reward Training Processing nn5_nn6-250124-111148...
# Reward Training Processing nn7_nn8-250124-122758...
# Reward Training Processing nn1-250124-052535...
# Reward Training Processing nn2-250124-052535...
# Reward Training Processing nn3-250124-064620...
# Reward Training Processing nn4-250124-064620...
# Reward Training Processing nn5-250124-111148...
# Reward Training Processing nn6-250124-111148...
# Reward Training Processing nn7-250124-122758...
# Reward Training Processing nn8-250124-122758...
# Subdirectories: ['nn1_nn2-250124-052535', 'nn3_nn4-250124-064620', 'nn5_nn6-250124-111148', 'nn7_nn8-250124-122758']
# dict_items([('n1-240529-073613', <trial_class.Trial object at 0x00000290BA9E35C0>), ('n2-240529-103052', <trial_class.Trial object at 0x00000290981AF2F0>), ('n3-240529-131000', <trial_class.Trial object at 0x00000290BA6E00E0>), ('n4-240529-154627', <trial_class.Trial object at 0x00000290BA5C7C50>), ('n5-240901-064209', <trial_class.Trial object at 0x00000290BA6496A0>), ('n6-240901-092648', <trial_class.Trial object at 0x00000290BAB45460>), ('n7-240901-115754', <trial_class.Trial object at 0x00000290BAB204A0>)])
# Reward Training Processing n1-240529-073613...
# Reward Training Processing n2-240529-103052...
# Reward Training Processing n3-240529-131000...
# Reward Training Processing n4-240529-154627...
# Reward Training Processing n5-240901-064209...
# Reward Training Processing n6-240901-092648...
# Reward Training Processing n7-240901-115754...
# Subdirectories: ['n1-240529-073613', 'n2-240529-103052', 'n3-240529-131000', 'n4-240529-154627', 'n5-240901-064209', 'n6-240901-092648', 'n7-240901-115754']
#             file name                                             trial  \
# 0   nn1-250124-052535  <trial_class.Trial object at 0x00000290BABC3CE0>
# 1   nn2-250124-052535  <trial_class.Trial object at 0x00000290BABEC380>
# 2   nn3-250124-064620  <trial_class.Trial object at 0x00000290F98937A0>
# 3   nn4-250124-064620  <trial_class.Trial object at 0x00000290F9891940>
# 4   nn5-250124-111148  <trial_class.Trial object at 0x00000290F98918E0>
# 5   nn6-250124-111148  <trial_class.Trial object at 0x00000290BA7AE540>
# 6   nn7-250124-122758  <trial_class.Trial object at 0x00000290F9892510>
# 7   nn8-250124-122758  <trial_class.Trial object at 0x000002909817BE00>
# 12   n5-240901-064209  <trial_class.Trial object at 0x00000290BA6496A0>
# 13   n6-240901-092648  <trial_class.Trial object at 0x00000290BAB45460>
# 14   n7-240901-115754  <trial_class.Trial object at 0x00000290BAB204A0>
#
#    subject_name                                         sound cues  \
# 0           nn1  {'name': 'PC0/', 'onset': [0.0, 241.63581952, ...
# 1           nn2  {'name': 'PC0/', 'onset': [0.0, 241.63581952, ...
# 2           nn3  {'name': 'PC0/', 'onset': [0.0, 243.5497984, 3...
# 3           nn4  {'name': 'PC0/', 'onset': [0.0, 243.5497984, 3...
# 4           nn5  {'name': 'PC0/', 'onset': [0.0, 241.29912832, ...
# 5           nn6  {'name': 'PC0/', 'onset': [0.0, 241.29912832, ...
# 6           nn7  {'name': 'PC0/', 'onset': [0.0, 241.03665664, ...
# 7           nn8  {'name': 'PC0/', 'onset': [0.0, 241.03665664, ...
# 12           n5  {'name': 'PC0/', 'onset': [0.0, 241.1544576, 3...
# 13           n6  {'name': 'PC0/', 'onset': [0.0, 240.7227392, 3...
# 14           n7  {'name': 'PC0/', 'onset': [0.0, 244.11406336, ...
#
#                                          port entries  \
# 0   {'name': 'PC2/', 'onset': [0.0, 199.71555328, ...
# 1   {'name': 'PC2/', 'onset': [0.0, 199.71555328, ...
# 2   {'name': 'PC2/', 'onset': [0.0, 210.82947584, ...
# 3   {'name': 'PC2/', 'onset': [0.0, 210.82947584, ...
# 4   {'name': 'PC2/', 'onset': [0.0, 260.76921856, ...
# 5   {'name': 'PC2/', 'onset': [0.0, 260.76921856, ...
# 6   {'name': 'PC2/', 'onset': [0.0, 189.28648192, ...
# 7   {'name': 'PC2/', 'onset': [0.0, 189.28648192, ...
# 12  {'name': 'PC3/', 'onset': [0.0, 191.6141568, 2...
# 13  {'name': 'PC3/', 'onset': [0.0, 186.57230848, ...
# 14  {'name': 'PC3/', 'onset': [0.0, 200.83376128, ...
#
#                                      sound cues onset  \
# 0   [241.63581952, 321.63627008, 411.63669504, 491...
# 1   [241.63581952, 321.63627008, 411.63669504, 491...
# 2   [243.5497984, 323.5504128, 413.55067392, 493.5...
# 3   [243.5497984, 323.5504128, 413.55067392, 493.5...
# 4   [241.29912832, 321.29974272, 411.30033152, 491...
# 5   [241.29912832, 321.29974272, 411.30033152, 491...
# 6   [241.03665664, 321.03727104, 411.03802368, 491...
# 7   [241.03665664, 321.03727104, 411.03802368, 491...
# 12  [241.1544576, 321.15474432, 411.15516928, 491....
# 13  [240.7227392, 320.72318976, 410.72361472, 490....
# 14  [244.11406336, 324.11435008, 414.11510272, 494...
#
#                                    port entries onset  \
# 0   [245.24570624, 248.8057856, 257.87613184, 260....
# 1   [245.24570624, 248.8057856, 257.87613184, 260....
# 2   [248.39962624, 275.23989504, 281.43992832, 288...
# 3   [248.39962624, 275.23989504, 281.43992832, 288...
# 4   [260.76921856, 272.71938048, 278.33942016, 281...
# 5   [260.76921856, 272.71938048, 278.33942016, 281...
# 6   [243.66678016, 294.1075456, 298.63723008, 305....
# 7   [243.66678016, 294.1075456, 298.63723008, 305....
# 12  [279.14452992, 284.18441216, 376.72517632, 380...
# 13  [269.39293696, 273.6627712, 275.75271424, 288....
# 14  [252.01393664, 261.43424512, 272.35418112, 297...
#
#                                   port entries offset
# 0   [245.5658496, 254.52593152, 259.20618496, 260....
# 1   [245.5658496, 254.52593152, 259.20618496, 260....
# 2   [274.71986688, 279.23972096, 287.45007104, 292...
# 3   [274.71986688, 279.23972096, 287.45007104, 292...
# 4   [269.32936704, 274.37940736, 279.25938176, 282...
# 5   [269.32936704, 274.37940736, 279.25938176, 282...
# 6   [290.28696064, 297.79689472, 300.17732608, 317...
# 7   [290.28696064, 297.79689472, 300.17732608, 317...
# 12  [283.43451648, 284.68461568, 379.1552512, 389....
# 13  [271.68309248, 274.41266688, 275.94293248, 288...
# 14  [260.93420544, 266.33404416, 273.30445312, 301...

# %%
exp.find_first_lick_after_sound_cue()
exp.compute_closest_port_offset(lick_column='first_lick_after_sound_cue', offset_column='port entries offset')
exp.compute_event_induced_DA()
exp.compute_lick_ei_DA()
exp.compute_tone_da()
exp.compute_lick_da()
exp.compute_tone_da(mode="EI")
exp.compute_lick_da(mode="EI")
print(exp.df['Lick Event_Zscore'])
# Out:
# 0     [[0.4021086571839566, 0.3992392425965227, 0.39...
# 1     [[-1.8229002981860944, -1.826002653944248, -1....
# 2     [[-1.1844603496442858, -1.1841214491952126, -1...
# 3     [[0.30470918267570224, 0.31450376043685935, 0....
# 4     [[3.101076362186964, 3.085230997629113, 3.0695...
# 5     [[4.141127608770498, 4.152101116268103, 4.1626...
# 6     [[1.1686622261727213, 1.1634908916718416, 1.15...
# 7     [[0.632632244253383, 0.6277236870186943, 0.622...
# 12    [[-0.0023718432895945126, -0.00387217009258715...
# 13    [[0.6485241479562411, 0.6479040784424467, 0.64...
# 14    [[-0.9263862603750072, -0.9254596381080801, -0...
# Name: Lick Event_Zscore, dtype: object

# %%
exp.plot_linear_fit_with_error_bars(directory_path='directory_path', color='blue', y_limits=None, brain_region='mPFC')
# Out:
# 'exp.apply_rc_plot_peth(exp.df, directory_path=directory_path)'

# %% [markdown]
# ## Plotting PETH of first and last tones

# %%
if brain_region == 'NAc':
    exp.plot_specific_peth(event_type='Tone', directory_path=directory_path, brain_region='NAc', y_min=-1.5, y_max=6.5)
    # exp.plot_specific_peth(event_type='Lick', directory_path=directory_path1, brain_region='NAc', y_min=-1.5, y_max=6)
else:
    exp.plot_specific_peth(event_type='Tone', directory_path=directory_path, brain_region='mPFC', y_min=-1.5, y_max=2.2)
    # exp.plot_specific_peth(event_type='Lick', directory_path=directory_path1, brain_region='mPFC', y_min=-1.3, y_max=1.5)
# Out:
# Row 0: Length of Z-score array: 41
# Row 1: Length of Z-score array: 41
# Row 2: Length of Z-score array: 40
# Row 3: Length of Z-score array: 40
# Row 4: Length of Z-score array: 40
# Row 5: Length of Z-score array: 40
# Row 6: Length of Z-score array: 40
# Row 7: Length of Z-score array: 40
# Row 12: Length of Z-score array: 16
# Row 13: Length of Z-score array: 16
# Row 14: Length of Z-score array: 20

# %% [markdown]
# ## Plotting Heatmaps

# %%
if brain_region == 'mPFC':
    exp.plot_trial_heatmaps(trial_numbers=15, event_type='Tone', directory_path=directory_path3, brain_region='mPFC')
else:
    exp.plot_trial_heatmaps(trial_numbers=15, event_type='Tone', directory_path=directory_path3, brain_region='NAc')

# %% [markdown]
# ## Plotting Linear with Global DA

# %% [markdown]
# ## Plotting Linear with Event-Induced DA

# %%
"""# Compute PETH around the first 5 sound cues
exp.rt_compute_peth_per_event(behavior_name='sound cues', n_events=14, pre_time=100, post_time=10, bin_size=0.1)

# Plot the PETH
exp.rt_plot_peth_per_event(signal_type='zscore', error_type='sem', title='PETH for First n Sound Cues',
                          color=brain_region, display_pre_time=4, display_post_time=10, yticks_interval=2)"""
# Out:
# "# Compute PETH around the first 5 sound cues\nexp.rt_compute_peth_per_event(behavior_name='sound cues', n_events=14, pre_time=100, post_time=10, bin_size=0.1)\n\n# Plot the PETH\nexp.rt_plot_peth_per_event(signal_type='zscore', error_type='sem', title='PETH for First n Sound Cues',\n                          color=brain_region, display_pre_time=4, display_post_time=10, yticks_interval=2)"

# %%
# # common_time_axis, peri_event_signals = exp.compute_peth_for_selected_events([14])
# # exp.plot_peth_for_all_sounds(common_time_axis, peri_event_signals)
# common_time_axis, peri_event_signals = exp.compute_peth_for_all_sounds()
# exp.plot_peth_for_all_sounds(common_time_axis, peri_event_signals)

# %%
exp.plot_linear_fit_with_error_bars(df, color=brain_region, y_limits=[-1,3])
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[11], line 1
# ----> 1 df = exp.compute_mean_da_across_trials()
#       2 df = df.iloc[1:].reset_index(drop=True)
#       3 exp.plot_linear_fit_with_error_bars(df, color=brain_region, y_limits=[-1,3])
#
# AttributeError: 'Reward_Training' object has no attribute 'compute_mean_da_across_trials'
